# %% [markdown]
# <a href="https://colab.research.google.com/github/todicode/ARIMA-model/blob/main/Test_ARIMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (0.14.5)
# Requirement already satisfied: numpy<3,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (2.0.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (1.16.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)

# %% [markdown]
# Như đoạn code của Tuấn Anh, dòng lệnh trên cho thấy thư viện statsmodels đã được cài sẵn trên ggcolab

# %% [markdown]
# # Kết nối google colab vào drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Nhớ phải cho gg colab kết nối với drive nha, nó sẽ gửi cái bảng yêu cầu kết nối với drive á, nhớ bấm tick hết mấy cái ô vuông nó gửi là được.

# %% [markdown]
# #Thêm các thư viện vào

# %%
import os
import warnings
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt
import math

from pandas.plotting import autocorrelation_plot
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.preprocessing import MinMaxScaler
from common.utils import load_data, mape
from IPython.display import Image

# %matplotlib inline
pd.options.display.float_format = '{:,.2f}'.format
np.set_printoptions(precision=2)
warnings.filterwarnings("ignore") # specify to ignore warning messages

# %% [markdown]
# Cell code này ban đầu bị lỗi này vì common không phải thư viện chuẩn của Python, và ta cũng chưa đưa file thư viện này vào cùng thư mục để chạy. Giải pháp: Đưa folder Common lên Driver, sau đó liên kết Driver với ggcolab để sử dụng file đó.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# => Câu lệnh này để liên kết Driver và colab, kết nối tại thư mục "/content/drive"

# %%
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Báo cáo 3')

from common.utils import load_data, mape

# %% [markdown]
# -import sys: gọi module hệ thống sys để làm việc với môi trường Python.
#
# -sys.path.append(...): bổ sung thư mục Google Drive (/content/drive/MyDrive/Colab Notebooks/Báo cáo 3) vào danh sách mà Python sẽ tìm kiếm khi import.
#
# -from common.utils import load_data, mape: nạp trực tiếp các hàm load_data và mape từ file utils.py nằm trong thư mục common trên Google Drive.

# %% [markdown]
# #Thêm lại thư viện sau khi fix lỗi

# %%
import os
import warnings
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime as dt
import math

from pandas.plotting import autocorrelation_plot
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.preprocessing import MinMaxScaler
from common.utils import load_data, mape
from IPython.display import Image

# %matplotlib inline
pd.options.display.float_format = '{:,.2f}'.format
np.set_printoptions(precision=2)
warnings.filterwarnings("ignore") # specify to ignore warning messages

# %%
energy = load_data('./data')[['load']]
energy.head(10)
# Out:
#                         load
# 2012-01-01 00:00:00 2,698.00
# 2012-01-01 01:00:00 2,558.00
# 2012-01-01 02:00:00 2,444.00
# 2012-01-01 03:00:00 2,402.00
# 2012-01-01 04:00:00 2,403.00
# 2012-01-01 05:00:00 2,453.00
# 2012-01-01 06:00:00 2,560.00
# 2012-01-01 07:00:00 2,719.00
# 2012-01-01 08:00:00 2,916.00
# 2012-01-01 09:00:00 3,105.00

# %% [markdown]
# Lúc đầu bị lỗi vì sai đường dẫn tới folder data, chỉ cần thực hiện dòng lệnh dưới đây là hết lỗi.

# %%
import os
os.chdir("/content/drive/MyDrive/Colab Notebooks/Báo cáo 3")

# ĐÚNG: truyền thư mục
energy = load_data("./data")[['load']]
energy.head()
# Out:
#                         load
# 2012-01-01 00:00:00 2,698.00
# 2012-01-01 01:00:00 2,558.00
# 2012-01-01 02:00:00 2,444.00
# 2012-01-01 03:00:00 2,402.00
# 2012-01-01 04:00:00 2,403.00

# %% [markdown]
# chdir = change directory.
#
# Lệnh này đổi thư mục làm việc hiện tại sang folder "Báo cáo 3" trong Google Drive của bạn.
#
# Sau lệnh này, mọi file bạn đọc/ghi sẽ mặc định nằm trong thư mục này (khỏi phải gõ đường dẫn dài dòng nữa).

# %% [markdown]
# load_data('./data') => hàm load_data (trong file common/utils.py) đọc dữ liệu từ thư mục ./data.Ở đây, nó đã đọc file energy.csv trong thư mục data.
#
# [['load']] => chọn đúng cột load nhưng giữ kết quả ở dạng DataFrame trong file dữ liệu (vì trong file gốc có nhiều cột hơn).
#
# Gán vào biến energy => lúc này energy chỉ chứa cột tải điện (load).
#
# energy.head() => hiển thị 5 dòng đầu tiên của dữ liệu để kiểm tra nhanh.

# %%
energy.plot(y='load', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()

# %% [markdown]
# => Lệnh này để vẽ biểu đồ cho biến energy. Cụ thể lệnh này thì tụi em chưa học đến.

# %% [markdown]
# # Tạo training và testing dataset

# %% [markdown]
# Bắt đầu tạo chia dataset thành 2 bộ data như thầy đã nói.

# %%
train_start_dt = '2014-11-01 00:00:00'
test_start_dt = '2014-12-30 00:00:00'

# %% [markdown]
# Lệnh này để gán biến, theo tụi em nghĩ là họ chia dataset thành 2 bộ.

# %%
energy[(energy.index < test_start_dt) & (energy.index >= train_start_dt)][['load']].rename(columns={'load':'train'}) \
    .join(energy[test_start_dt:][['load']].rename(columns={'load':'test'}), how='outer') \
    .plot(y=['train', 'test'], figsize=(15, 8), fontsize=12)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()

# %% [markdown]
# => Đoạn lệnh này lại dùng để vẽ biểu đồ.

# %%
train = energy.copy()[(energy.index >= train_start_dt) & (energy.index < test_start_dt)][['load']]
test = energy.copy()[energy.index >= test_start_dt][['load']]

print('Training data shape: ', train.shape)
print('Test data shape: ', test.shape)
# Out:
# Training data shape:  (1416, 1)
# Test data shape:  (48, 1)

# %% [markdown]
# train = energy.copy(): Tạo bản sao cho energy để tránh ảnh hưởng dữ liệu ban đầu.
# [(energy.index >= train_start_dt) & (energy.index < test_start_dt)][['load']]: chọn các dòng có thời gian nằm trong khoảng từ train_start_dt đến trước test_start_dt.
# [['load']]: Chỉ giữ lại cột "load".
# Dòng 1 để chọn tập train.
# print(train.shape): in ra số hàng và cột của tập train => Bước này để kiểm tra xem tách đúng chưa.
# Tập test cũng tương tự.

# %%
scaler = MinMaxScaler()
train['load'] = scaler.fit_transform(train)
train.head(10)
# Out:
#                      load
# 2014-11-01 00:00:00  0.10
# 2014-11-01 01:00:00  0.07
# 2014-11-01 02:00:00  0.05
# 2014-11-01 03:00:00  0.04
# 2014-11-01 04:00:00  0.06
# 2014-11-01 05:00:00  0.10
# 2014-11-01 06:00:00  0.19
# 2014-11-01 07:00:00  0.31
# 2014-11-01 08:00:00  0.40
# 2014-11-01 09:00:00  0.48

# %% [markdown]
# => Điều chỉnh dữ liệu theo phạm vi (0, 1)

# %%
energy[(energy.index >= train_start_dt) & (energy.index < test_start_dt)][['load']].rename(columns={'load':'original load'}).plot.hist(bins=100, fontsize=12)
train.rename(columns={'load':'scaled load'}).plot.hist(bins=100, fontsize=12)
plt.show()

# %% [markdown]
# Đoạn mã này để vẽ biểu đồ cho dữ liệu gốc trước và sau khi train => Hình dung dữ liệu gốc so với dữ liệu đã thu nhỏ. Ở đây biến x đã được thu nhỏ lại

# %%
test['load'] = scaler.transform(test)
test.head()
# Out:
#                      load
# 2014-12-30 00:00:00  0.33
# 2014-12-30 01:00:00  0.29
# 2014-12-30 02:00:00  0.27
# 2014-12-30 03:00:00  0.27
# 2014-12-30 04:00:00  0.30

# %% [markdown]
# - Bây giờ bạn đã hiệu chỉnh dữ liệu đã chia tỷ lệ, bạn có thể chia tỷ lệ dữ liệu thử nghiệm. (Đoạn này tụi em chưa hiểu họ nói gì lắm).

# %%
# Specify the number of steps to forecast ahead
HORIZON = 2 #trong github để = 3
print('Forecasting horizon:', HORIZON, 'hours')
# Out:
# Forecasting horizon: 2 hours

# %%
order = (4, 1, 0)
seasonal_order = (1, 1, 0, 24)

model = SARIMAX(endog=train, order=order, seasonal_order=seasonal_order)
results = model.fit()

print(results.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                               load   No. Observations:                 1416
# Model:             SARIMAX(4, 1, 0)x(1, 1, 0, 24)   Log Likelihood                3477.240
# Date:                            Sat, 06 Sep 2025   AIC                          -6942.479
# Time:                                    12:12:40   BIC                          -6911.052
# Sample:                                11-01-2014   HQIC                         -6930.727
#                                      - 12-29-2014
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8413      0.016     52.209      0.000       0.810       0.873
# ar.L2         -0.5222      0.034    -15.379      0.000      -0.589      -0.456
# ar.L3          0.1529      0.044      3.456      0.001       0.066       0.240
# ar.L4         -0.0779      0.036     -2.162      0.031      -0.149      -0.007
# ar.S.L24      -0.2340      0.024     -9.790      0.000      -0.281      -0.187
# sigma2         0.0004   8.32e-06     47.359      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):              1464.29
# Prob(Q):                              0.80   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.84   Skew:                             0.14
# Prob(H) (two-sided):                  0.06   Kurtosis:                         8.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
test_shifted = test.copy()

for t in range(1, HORIZON+1):
    test_shifted['load+'+str(t)] = test_shifted['load'].shift(-t, freq='H') # Sửa Horizon = 2 thì output giống output github, để horizon = 3 thì output thừa 1 cột so với git

test_shifted = test_shifted.dropna(how='any')
test_shifted.head(5)
# Out:
#                      load  load+1  load+2
# 2014-12-30 00:00:00  0.33    0.29    0.27
# 2014-12-30 01:00:00  0.29    0.27    0.27
# 2014-12-30 02:00:00  0.27    0.27    0.30
# 2014-12-30 03:00:00  0.27    0.30    0.41
# 2014-12-30 04:00:00  0.30    0.41    0.57

# %%
# %%time
training_window = 720 # dedicate 30 days (720 hours) for training

train_ts = train['load']
test_ts = test_shifted

history = [x for x in train_ts]
history = history[(-training_window):]

predictions = list()

order = (2, 1, 0)
seasonal_order = (1, 1, 0, 24)

for t in range(test_ts.shape[0]):
    model = SARIMAX(endog=history, order=order, seasonal_order=seasonal_order)
    model_fit = model.fit()
    yhat = model_fit.forecast(steps = HORIZON)
    predictions.append(yhat)
    obs = list(test_ts.iloc[t])
    # move the training window
    history.append(obs[0])
    history.pop(0)
    print(test_ts.index[t])
    print(t+1, ': predicted =', yhat, 'expected =', obs)
# Out:
# 2014-12-30 00:00:00
# 1 : predicted = [0.32 0.29 0.28] expected = [0.32945389435989236, 0.2900626678603402, 0.2739480752014323, 0.26812891674127126]
# 2014-12-30 01:00:00
# 2 : predicted = [0.3  0.29 0.3 ] expected = [0.2900626678603402, 0.2739480752014323, 0.26812891674127126, 0.3025962399283795]
# 2014-12-30 02:00:00
# 3 : predicted = [0.27 0.28 0.32] expected = [0.2739480752014323, 0.26812891674127126, 0.3025962399283795, 0.40823634735899716]
# 2014-12-30 03:00:00
# 4 : predicted = [0.28 0.32 0.42] expected = [0.26812891674127126, 0.3025962399283795, 0.40823634735899716, 0.5689346463742166]
# 2014-12-30 04:00:00
# 5 : predicted = [0.3  0.39 0.54] expected = [0.3025962399283795, 0.40823634735899716, 0.5689346463742166, 0.6799462846911368]
# 2014-12-30 05:00:00
# 6 : predicted = [0.4  0.55 0.66] expected = [0.40823634735899716, 0.5689346463742166, 0.6799462846911368, 0.7309758281110115]
# 2014-12-30 06:00:00
# 7 : predicted = [0.57 0.68 0.75] expected = [0.5689346463742166, 0.6799462846911368, 0.7309758281110115, 0.7511190689346463]
# 2014-12-30 07:00:00
# 8 : predicted = [0.68 0.75 0.8 ] expected = [0.6799462846911368, 0.7309758281110115, 0.7511190689346463, 0.7636526410026856]
# 2014-12-30 08:00:00
# 9 : predicted = [0.75 0.8  0.82] expected = [0.7309758281110115, 0.7511190689346463, 0.7636526410026856, 0.7381378692927483]
# 2014-12-30 09:00:00
# 10 : predicted = [0.76 0.78 0.78] expected = [0.7511190689346463, 0.7636526410026856, 0.7381378692927483, 0.7188898836168307]
# 2014-12-30 10:00:00
# 11 : predicted = [0.76 0.75 0.74] expected = [0.7636526410026856, 0.7381378692927483, 0.7188898836168307, 0.7090420769919425]
# 2014-12-30 11:00:00
# 12 : predicted = [0.77 0.76 0.75] expected = [0.7381378692927483, 0.7188898836168307, 0.7090420769919425, 0.7081468218442255]
# 2014-12-30 12:00:00
# 13 : predicted = [0.7  0.68 0.69] expected = [0.7188898836168307, 0.7090420769919425, 0.7081468218442255, 0.7385854968666068]
# 2014-12-30 13:00:00
# 14 : predicted = [0.72 0.73 0.76] expected = [0.7090420769919425, 0.7081468218442255, 0.7385854968666068, 0.8478066248880931]
# 2014-12-30 14:00:00
# 15 : predicted = [0.71 0.73 0.86] expected = [0.7081468218442255, 0.7385854968666068, 0.8478066248880931, 0.9516562220232765]
# 2014-12-30 15:00:00
# 16 : predicted = [0.73 0.85 0.97] expected = [0.7385854968666068, 0.8478066248880931, 0.9516562220232765, 0.934198746642793]
# 2014-12-30 16:00:00
# 17 : predicted = [0.87 0.99 0.97] expected = [0.8478066248880931, 0.9516562220232765, 0.934198746642793, 0.8876454789615038]
# 2014-12-30 17:00:00
# 18 : predicted = [0.94 0.92 0.86] expected = [0.9516562220232765, 0.934198746642793, 0.8876454789615038, 0.8294538943598924]
# 2014-12-30 18:00:00
# 19 : predicted = [0.94 0.89 0.82] expected = [0.934198746642793, 0.8876454789615038, 0.8294538943598924, 0.7197851387645477]
# 2014-12-30 19:00:00
# 20 : predicted = [0.88 0.82 0.71] expected = [0.8876454789615038, 0.8294538943598924, 0.7197851387645477, 0.5747538048343777]
# 2014-12-30 20:00:00
# 21 : predicted = [0.83 0.72 0.58] expected = [0.8294538943598924, 0.7197851387645477, 0.5747538048343777, 0.4592658907788718]
# 2014-12-30 21:00:00
# 22 : predicted = [0.72 0.58 0.47] expected = [0.7197851387645477, 0.5747538048343777, 0.4592658907788718, 0.3858549686660697]
# 2014-12-30 22:00:00
# 23 : predicted = [0.58 0.47 0.39] expected = [0.5747538048343777, 0.4592658907788718, 0.3858549686660697, 0.34377797672336596]
# 2014-12-30 23:00:00
# 24 : predicted = [0.46 0.38 0.34] expected = [0.4592658907788718, 0.3858549686660697, 0.34377797672336596, 0.32542524619516544]
# 2014-12-31 00:00:00
# 25 : predicted = [0.38 0.34 0.33] expected = [0.3858549686660697, 0.34377797672336596, 0.32542524619516544, 0.33034914950760963]
# 2014-12-31 01:00:00
# 26 : predicted = [0.36 0.34 0.34] expected = [0.34377797672336596, 0.32542524619516544, 0.33034914950760963, 0.3706356311548791]
# 2014-12-31 02:00:00
# 27 : predicted = [0.32 0.32 0.35] expected = [0.32542524619516544, 0.33034914950760963, 0.3706356311548791, 0.470008952551477]
# 2014-12-31 03:00:00
# 28 : predicted = [0.32 0.36 0.47] expected = [0.33034914950760963, 0.3706356311548791, 0.470008952551477, 0.6145926589077886]
# 2014-12-31 04:00:00
# 29 : predicted = [0.37 0.48 0.65] expected = [0.3706356311548791, 0.470008952551477, 0.6145926589077886, 0.7247090420769919]
# 2014-12-31 05:00:00
# 30 : predicted = [0.48 0.64 0.75] expected = [0.470008952551477, 0.6145926589077886, 0.7247090420769919, 0.786034019695613]
# 2014-12-31 06:00:00
# 31 : predicted = [0.63 0.73 0.79] expected = [0.6145926589077886, 0.7247090420769919, 0.786034019695613, 0.8012533572068039]
# 2014-12-31 07:00:00
# 32 : predicted = [0.71 0.76 0.79] expected = [0.7247090420769919, 0.786034019695613, 0.8012533572068039, 0.7994628469113696]
# 2014-12-31 08:00:00
# 33 : predicted = [0.79 0.82 0.83] expected = [0.786034019695613, 0.8012533572068039, 0.7994628469113696, 0.780214861235452]
# 2014-12-31 09:00:00
# 34 : predicted = [0.82 0.83 0.81] expected = [0.8012533572068039, 0.7994628469113696, 0.780214861235452, 0.7587287376902416]
# 2014-12-31 10:00:00
# 35 : predicted = [0.8  0.78 0.76] expected = [0.7994628469113696, 0.780214861235452, 0.7587287376902416, 0.7367949865711727]
# 2014-12-31 11:00:00
# 36 : predicted = [0.77 0.75 0.74] expected = [0.780214861235452, 0.7587287376902416, 0.7367949865711727, 0.7188898836168307]
# 2014-12-31 12:00:00
# 37 : predicted = [0.77 0.76 0.76] expected = [0.7587287376902416, 0.7367949865711727, 0.7188898836168307, 0.7273948075201431]
# 2014-12-31 13:00:00
# 38 : predicted = [0.75 0.75 0.78] expected = [0.7367949865711727, 0.7188898836168307, 0.7273948075201431, 0.8299015219337511]
# 2014-12-31 14:00:00
# 39 : predicted = [0.73 0.75 0.87] expected = [0.7188898836168307, 0.7273948075201431, 0.8299015219337511, 0.909579230080573]
# 2014-12-31 15:00:00
# 40 : predicted = [0.74 0.85 0.96] expected = [0.7273948075201431, 0.8299015219337511, 0.909579230080573, 0.855863921217547]
# 2014-12-31 16:00:00
# 41 : predicted = [0.83 0.94 0.93] expected = [0.8299015219337511, 0.909579230080573, 0.855863921217547, 0.7721575649059982]
# 2014-12-31 17:00:00
# 42 : predicted = [0.94 0.93 0.88] expected = [0.909579230080573, 0.855863921217547, 0.7721575649059982, 0.7023276633840643]
# 2014-12-31 18:00:00
# 43 : predicted = [0.87 0.82 0.77] expected = [0.855863921217547, 0.7721575649059982, 0.7023276633840643, 0.6195165622202325]
# 2014-12-31 19:00:00
# 44 : predicted = [0.79 0.73 0.63] expected = [0.7721575649059982, 0.7023276633840643, 0.6195165622202325, 0.5425246195165621]
# 2014-12-31 20:00:00
# 45 : predicted = [0.7  0.59 0.46] expected = [0.7023276633840643, 0.6195165622202325, 0.5425246195165621, 0.4735899731423454]
# CPU times: user 6min 54s, sys: 566 ms, total: 6min 55s
# Wall time: 4min 12s

# %%
eval_df = pd.DataFrame(predictions, columns=['t+'+str(t) for t in range(1, HORIZON+1)])
eval_df['timestamp'] = test.index[0:len(test.index)-HORIZON+1]
eval_df = pd.melt(eval_df, id_vars='timestamp', value_name='prediction', var_name='h')
eval_df['actual'] = np.array(np.transpose(test_ts)).ravel()
eval_df[['prediction', 'actual']] = scaler.inverse_transform(eval_df[['prediction', 'actual']])
eval_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2465955293.py in <cell line: 0>()
#       1 eval_df = pd.DataFrame(predictions, columns=['t+'+str(t) for t in range(1, HORIZON+1)])
# ----> 2 eval_df['timestamp'] = test.index[0:len(test.index)-HORIZON+1]
#       3 eval_df = pd.melt(eval_df, id_vars='timestamp', value_name='prediction', var_name='h')
#       4 eval_df['actual'] = np.array(np.transpose(test_ts)).ravel()
#       5 eval_df[['prediction', 'actual']] = scaler.inverse_transform(eval_df[['prediction', 'actual']])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4309         else:
#    4310             # set column
# -> 4311             self._set_item(key, value)
#    4312
#    4313     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4522         ensure homogeneity.
#    4523         """
# -> 4524         value, refs = self._sanitize_column(value)
#    4525
#    4526         if (
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    5264
#    5265         if is_list_like(value):
# -> 5266             com.require_length_match(value, self.index)
#    5267         arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268         if (
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     571     """
#     572     if len(data) != len(index):
# --> 573         raise ValueError(
#     574             "Length of values "
#     575             f"({len(data)}) "
#
# ValueError: Length of values (47) does not match length of index (46)

# %% [markdown]
# đoạn này bị lỗi không khớp dữ liệu. Làm theo github nhưng không biết tại sao lại không ra đúng output, có thể họ chụp lộn ảnh rồi up lên github. Ví dụ như đoạn set Horizon = 3 ở trên, phải set Horizon = 2 thì mới không thừa cột load+3 được, nhưng trên github lại set Horizon = 3.
#
# Giải pháp: Nhờ Gemini trong google colab sửa lại như đoạn bên dưới đây.

# %%
eval_df = pd.DataFrame(predictions, index=test_ts.index, columns=['t+'+str(t) for t in range(1, HORIZON+1)])
eval_df = pd.melt(eval_df.reset_index(), id_vars='index', value_name='prediction', var_name='h')
eval_df = eval_df.rename(columns={'index':'timestamp'})

# Flatten test_ts to match the shape of eval_df after melting
actual_values = np.array(test_ts[['load+'+str(t) for t in range(1, HORIZON+1)]]).ravel()
eval_df['actual'] = actual_values

eval_df[['prediction', 'actual']] = scaler.inverse_transform(eval_df[['prediction', 'actual']])
eval_df.head()
# Out:
#             timestamp    h  prediction   actual
# 0 2014-12-30 00:00:00  t+1    3,008.78 2,935.00
# 1 2014-12-30 01:00:00  t+1    2,955.62 2,899.00
# 2 2014-12-30 02:00:00  t+1    2,900.21 2,886.00
# 3 2014-12-30 03:00:00  t+1    2,917.56 2,899.00
# 4 2014-12-30 04:00:00  t+1    2,946.62 2,886.00

# %% [markdown]
# Đã fix được lỗi, mặc dù tụi em không hiểu Gemini fix như nào do tụi em chưa học tới.

# %% [markdown]
# #Kiểm tra sự chính xác của mô hình

# %%
if(HORIZON > 1):
    eval_df['APE'] = (eval_df['prediction'] - eval_df['actual']).abs() / eval_df['actual']
    print(eval_df.groupby('h')['APE'].mean())
# Out:
# h
# t+1   0.11
# t+2   0.16
# t+3   0.11
# Name: APE, dtype: float64

# %%
print('One step forecast MAPE: ', (mape(eval_df[eval_df['h'] == 't+1']['prediction'], eval_df[eval_df['h'] == 't+1']['actual']))*100, '%')
# Out:
# One step forecast MAPE:  10.595076868986732 %

# %%
print('Multi-step forecast MAPE: ', mape(eval_df['prediction'], eval_df['actual'])*100, '%')
# Out:
# Multi-step forecast MAPE:  12.448531143432838 %

# %%
 if(HORIZON == 1):
    ## Plotting single step forecast
    eval_df.plot(x='timestamp', y=['actual', 'prediction'], style=['r', 'b'], figsize=(15, 8))

else:
    ## Plotting multi step forecast
    plot_df = eval_df[(eval_df.h=='t+1')][['timestamp', 'actual']]
    for t in range(1, HORIZON+1):
        plot_df['t+'+str(t)] = eval_df[(eval_df.h=='t+'+str(t))]['prediction'].values

    fig = plt.figure(figsize=(15, 8))
    ax = plt.plot(plot_df['timestamp'], plot_df['actual'], color='red', linewidth=4.0)
    ax = fig.add_subplot(111)
    for t in range(1, HORIZON+1):
        x = plot_df['timestamp'][(t-1):]
        y = plot_df['t+'+str(t)][0:len(x)]
        ax.plot(x, y, color='blue', linewidth=4*math.pow(.9,t), alpha=math.pow(0.8,t))

    ax.legend(loc='best')

plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()
